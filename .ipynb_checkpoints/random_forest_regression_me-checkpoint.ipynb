# %% [markdown]
# # Random Forest Regression

# %% [markdown]
# ## Importing the libraries

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# ## Importing the dataset

# %%
dataset = pd.read_csv('Position_Salaries.csv')
X = dataset.iloc[:, 1:-1].values
y = dataset.iloc[:, -1].values

# %% [markdown]
# ## Training the Random Forest Regression model on the whole dataset

# %%
from sklearn.ensemble import RandomForestRegressor
max_depth = 500
regressor = RandomForestRegressor(random_state=0 , max_depth=max_depth)
regressor.fit(X,y)
# Out:
# RandomForestRegressor(max_depth=500, random_state=0)

# %% [markdown]
# ## Predicting a new result

# %%
# Out:
# array([158300.])

# %% [markdown]
# ## Visualising the Random Forest Regression results (higher resolution)

# %%
# Out:
# /var/folders/r9/lxplj4cx1lqf2f9cj282_ryc0000gn/T/ipykernel_22382/2476355806.py:1: DeprecationWarning: Conversion of an array with ndim > 0 to a scalar is deprecated, and will error in future. Ensure you extract a single element from your array before performing this operation. (Deprecated NumPy 1.25.)
#   X_grid = np.arange(min(X) , max(X) , 0.01)
